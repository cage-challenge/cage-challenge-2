# %%
import inspect
import time
from statistics import mean, stdev
from CybORG import CybORG
from CybORG.Agents import B_lineAgent, SleepAgent, GreenAgent
from CybORG.Agents.SimpleAgents.BaseAgent import BaseAgent
from CybORG.Agents.SimpleAgents.BlueReactAgent import BlueReactRemoveAgent
from CybORG.Agents.SimpleAgents.Meander import RedMeanderAgent
from CybORG.Agents.Wrappers.EnumActionWrapper import EnumActionWrapper
from CybORG.Agents.Wrappers.FixedFlatWrapper import FixedFlatWrapper
from CybORG.Agents.Wrappers.OpenAIGymWrapper import OpenAIGymWrapper
from CybORG.Agents.Wrappers.ReduceActionSpaceWrapper import ReduceActionSpaceWrapper
from CybORG.Agents.Wrappers import ChallengeWrapper
import os

from ray.tune.registry import register_env
from CybORG.Agents.Wrappers.rllib_wrapper import RLlibWrapper
import warnings
import numpy as np
from ray import air, tune
warnings.filterwarnings('ignore')

# %%
def env_creator(env_config: dict):
    path = str(inspect.getfile(CybORG))
    path = path[:-10] + '/Shared/Scenarios/Scenario2.yaml'
    agents = {"Red": B_lineAgent, "Green": GreenAgent}
    cyborg = CybORG(scenario_file=path, environment='sim', agents=agents)
    env = RLlibWrapper(env=cyborg, agent_name="Blue", max_steps=100)
    return env

def print_results(results_dict):
    train_iter = results_dict["training_iteration"]
    r_mean = results_dict["episode_reward_mean"]
    r_max = results_dict["episode_reward_max"]
    r_min = results_dict["episode_reward_min"]
    print(f"{train_iter:4d} \tr_mean: {r_mean:.1f} \tr_max: {r_max:.1f} \tr_min: {r_min: .1f}")

register_env(name="CybORG", env_creator=env_creator)

# %%
from ray import air, tune

tune.Tuner(
        "APPO",
        run_config=air.RunConfig(
            stop={"timesteps_total": 2e6},
            local_dir='results/APPO', name="tune",
            checkpoint_config=air.CheckpointConfig(
                checkpoint_frequency=500,
                
            ),
        ),
        param_space={
            # CC3 specific.
            "env": "CybORG",
            # General
            "num_gpus": 1,
            "num_workers": 20,
            "num_envs_per_worker": 1,
            #algo params
            "train_batch_size": tune.grid_search([6000]),
            "lr": tune.grid_search([0.001, 0.0005, 0.0001]),
            "gamma": tune.grid_search([0.99]),
            "framework": 'tf',
            "use_kl_loss": True,
            "kl_target": tune.grid_search([0.1]),
            # Method specific.
        },
    ).fit()
# Out:
# 2022-12-01 15:17:46,057	INFO worker.py:1528 -- Started a local Ray instance.
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2022-12-01 15:22:01</td></tr>
# <tr><td>Running for: </td><td>00:04:13.24        </td></tr>
# <tr><td>Memory:      </td><td>100.2/125.8 GiB    </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Resources requested: 21.0/40 CPUs, 1.0/1 GPUs, 0.0/78.28 GiB heap, 0.0/37.54 GiB objects (0.0/1.0 accelerator_type:V100)
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
#   ... 25 more trials not shown (25 PENDING)
#
# </div>
# <style>
# .messages {
#   color: var(--jp-ui-font-color1);
#   display: flex;
#   flex-direction: column;
#   padding-left: 1em;
#   overflow-y: auto;
# }
# .messages h3 {
#   font-weight: bold;
# }
# .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name             </th><th>status  </th><th>loc            </th><th style="text-align: right;">  gamma</th><th style="text-align: right;">  kl_target</th><th style="text-align: right;">   lr</th><th style="text-align: right;">  train_batch_size</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  num_recreated_worker
# s</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th></tr>
# </thead>
# <tbody>
# <tr><td>APPO_CybORG_506fc_00000</td><td>RUNNING </td><td>172.28.0.2:1387</td><td style="text-align: right;">   0.99</td><td style="text-align: right;">        0.1</td><td style="text-align: right;">0.001</td><td style="text-align: right;">              6000</td><td style="text-align: right;">    19</td><td style="text-align: right;">         216.025</td><td style="text-align: right;">287950</td><td style="text-align: right;">-226.863</td><td style="text-align: right;">0</td><td style="text-align: right;">              -148.8</td><td style="text-align: right;">              -294.8</td></tr>
# <tr><td>APPO_CybORG_506fc_00001</td><td>PENDING </td><td>               </td><td style="text-align: right;">   0.98</td><td style="text-align: right;">        0.1</td><td style="text-align: right;">0.001</td><td style="text-align: right;">              6000</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">      </td><td style="text-align: right;">        </td><td style="text-align: right;"> </td><td style="text-align: right;">                    </td><td style="text-align: right;">                    </td></tr>
# <tr><td>APPO_CybORG_506fc_00002</td><td>PENDING </td><td>               </td><td style="text-align: right;">   0.97</td><td style="text-align: right;">        0.1</td><td style="text-align: right;">0.001</td><td style="text-align: right;">              6000</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">      </td><td style="text-align: right;">        </td><td style="text-align: right;"> </td><td style="text-align: right;">                    </td><td style="text-align: right;">                    </td></tr>
# <tr><td>APPO_CybORG_506fc_00003</td><td>PENDING </td><td>               </td><td style="text-align: right;">   0.99</td><td style="text-align: right;">        0.2</td><td style="text-align: right;">0.001</td><td style="text-align: right;">              6000</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">      </td><td style="text-align: right;">        </td><td style="text-align: right;"> </td><td style="text-align: right;">                    </td><td style="text-align: right;">                    </td></tr>
# <tr><td>APPO_CybORG_506fc_00004</td><td>PENDING </td><td>               </td><td style="text-align: right;">   0.98</td><td style="text-align: right;">        0.2</td><td style="text-align: right;">0.001</td><td style="text-align: right;">              6000</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">      </td><td style="text-align: right;">        </td><td style="text-align: right;"> </td><td style="text-align: right;">                    </td><td style="text-align: right;">                    </td></tr>
# <tr><td>APPO_CybORG_506fc_00005</td><td>PENDING </td><td>               </td><td style="text-align: right;">   0.97</td><td style="text-align: right;">        0.2</td><td style="text-align: right;">0.001</td><td style="text-align: right;">              6000</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">      </td><td style="text-align: right;">        </td><td style="text-align: right;"> </td><td style="text-align: right;">                    </td><td style="text-align: right;">                    </td></tr>
# <tr><td>APPO_CybORG_506fc_00006</td><td>PENDING </td><td>               </td><td style="text-align: right;">   0.99</td><td style="text-align: right;">        0.1</td><td style="text-align: right;">0.002</td><td style="text-align: right;">              6000</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">      </td><td style="text-align: right;">        </td><td style="text-align: right;"> </td><td style="text-align: right;">                    </td><td style="text-align: right;">                    </td></tr>
# <tr><td>APPO_CybORG_506fc_00007</td><td>PENDING </td><td>               </td><td style="text-align: right;">   0.98</td><td style="text-align: right;">        0.1</td><td style="text-align: right;">0.002</td><td style="text-align: right;">              6000</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">      </td><td style="text-align: right;">        </td><td style="text-align: right;"> </td><td style="text-align: right;">                    </td><td style="text-align: right;">                    </td></tr>
# <tr><td>APPO_CybORG_506fc_00008</td><td>PENDING </td><td>               </td><td style="text-align: right;">   0.97</td><td style="text-align: right;">        0.1</td><td style="text-align: right;">0.002</td><td style="text-align: right;">              6000</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">      </td><td style="text-align: right;">        </td><td style="text-align: right;"> </td><td style="text-align: right;">                    </td><td style="text-align: right;">                    </td></tr>
# <tr><td>APPO_CybORG_506fc_00009</td><td>PENDING </td><td>               </td><td style="text-align: right;">   0.99</td><td style="text-align: right;">        0.2</td><td style="text-align: right;">0.002</td><td style="text-align: right;">              6000</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">      </td><td style="text-align: right;">        </td><td style="text-align: right;"> </td><td style="text-align: right;">                    </td><td style="text-align: right;">                    </td></tr>
# <tr><td>APPO_CybORG_506fc_00010</td><td>PENDING </td><td>               </td><td style="text-align: right;">   0.98</td><td style="text-align
# (APPO pid=1387) 2022-12-01 15:17:56,110	INFO algorithm.py:2303 -- Your framework setting is 'tf', meaning you are using static-graph mode. Set framework='tf2' to enable eager execution with tf2.x. You may also then want to set eager_tracing=True in order to reach similar execution speed as with static-graph mode.
# (APPO pid=1387) 2022-12-01 15:17:56,112	INFO algorithm.py:457 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (RolloutWorker pid=1419) 2022-12-01 15:18:06,140	WARNING env.py:147 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (APPO pid=1387) 2022-12-01 15:18:14,174	INFO trainable.py:164 -- Trainable.setup took 18.066 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# (APPO pid=1387) 2022-12-01 15:18:14,175	WARNING util.py:66 -- Install gputil for GPU system monitoring.
# (APPO pid=1387) 2022-12-01 15:18:14,889	WARNING deprecation.py:47 -- DeprecationWarning: `concat_samples` has been deprecated. Use `concat_samples() from rllib.policy.sample_batch` instead. This will raise an error in the future!
# (APPO pid=1387) 2022-12-01 15:18:14,895	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:14,917	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:14,925	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:14,936	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:14,947	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:14,956	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:14,965	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:14,973	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:14,983	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:15,577	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:15,605	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:15,620	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:15,627	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:15,636	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:15,645	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:15,653	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:15,664	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:15,677	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:15,686	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:15,709	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:15,727	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:15,773	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:16,158	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:16,197	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:16,219	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:16,226	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:16,232	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:16,244	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:16,257	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:16,269	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:16,281	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:16,293	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:16,305	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:16,318	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:16,336	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:16,343	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,198	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,206	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,215	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,237	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,280	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,296	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,304	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,314	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,343	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,350	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,358	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,383	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,389	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,395	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,401	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,410	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,424	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,464	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,807	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,819	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,832	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,850	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,874	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,908	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,925	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,935	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,943	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,956	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,963	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,970	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,976	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,986	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:17,998	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:18,004	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:18,024	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:18,031	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:18,037	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:18,104	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:18,559	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:18,575	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:18,596	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:18,602	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:18,619	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:18,625	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:18,642	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:18,650	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:18,662	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:18,678	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:18,695	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:18,702	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:18,729	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:18,735	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:18,742	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:18,764	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:18,774	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:18,781	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:18,867	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:18,893	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:20,166	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:20,200	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:20,216	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:20,781	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:20,828	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:20,876	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:20,914	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:21,474	WARNING appo.py:265 -- No data for default_policy, not updating kl
# (APPO pid=1387) 2022-12-01 15:18:21,482	WARNING appo.py:265 -- No data for default_policy, not updating kl
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name             </th><th style="text-align: right;">  agent_timesteps_total</th><th>counters                                                                                                                                                                                                                                                                                                                                 </th><th>custom_metrics  </th><th>date               </th><th>done  </th><th style="text-align: right;">  episode_len_mean</th><th>episode_media  </th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_mean</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episodes_this_iter</th><th style="text-align: right;">  episodes_total</th><th>experiment_id                   </th><th>hostname    </th><th>info                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        </th><th style="text-align: right;">  iterations_since_restore</th><th>node_ip   </th><th style="text-align: right;">  num_agent_steps_sampled</th><th style="text-align: right;">  num_agent_steps_trained</th><th style="text-align: right;">  num_env_steps_sampled</th><th style="text-align: right;">  num_env_steps_sampled_this_iter</th><th style="text-align: right;">  num_env_steps_trained</th><th style="text-align: right;">  num_env_steps_trained_this_iter</th><th style="text-align: right;">  num_faulty_episodes</th><th style="text-align: right;">  num_healthy_workers</th><th style="text-align: right;">  num_recreated_workers</th><th style="text-align: right;">  num_steps_trained_this_iter</th><th>perf                                                             </th><th style="text-align: right;">  pid</th><th>policy_reward_max  </th><th>policy_reward_mean  </th><th>policy_reward_min  </th><th>sampler_perf                                                                                                                                                                                                  </th><th>sampler_results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# 2022-12-01 15:22:03,930	WARNING tune.py:705 -- Stop signal received (e.g. via SIGINT/Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C (or send SIGINT/SIGKILL/SIGTERM) to skip.

# %%
tune.__version__

# %%
# !pip show ray
# Out:
# Name: ray
# Version: 2.1.0
# Summary: Ray provides a simple, universal API for building distributed applications.
# Home-page: https://github.com/ray-project/ray
# Author: Ray Team
# Author-email: ray-dev@googlegroups.com
# License: Apache 2.0
# Location: /usr/local/lib/python3.8/dist-packages
# Requires: msgpack, virtualenv, jsonschema, attrs, protobuf, pyyaml, requests, numpy, click, frozenlist, filelock, grpcio, aiosignal
# Required-by:
