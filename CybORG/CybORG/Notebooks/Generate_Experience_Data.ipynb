# %%
import inspect
import time
from statistics import mean, stdev
from CybORG import CybORG
from CybORG.Agents import B_lineAgent, SleepAgent, GreenAgent, RedMeanderAgent
from CybORG.Agents.SimpleAgents.BaseAgent import BaseAgent
from CybORG.Agents.SimpleAgents.BlueReactAgent import BlueReactRemoveAgent
from CybORG.Agents.SimpleAgents.Meander import RedMeanderAgent
from CybORG.Agents.Wrappers.EnumActionWrapper import EnumActionWrapper
from CybORG.Agents.Wrappers.FixedFlatWrapper import FixedFlatWrapper
from CybORG.Agents.Wrappers.OpenAIGymWrapper import OpenAIGymWrapper
from CybORG.Agents.Wrappers.ReduceActionSpaceWrapper import ReduceActionSpaceWrapper
from CybORG.Agents.Wrappers import ChallengeWrapper
import os

from ray.tune.registry import register_env
from CybORG.Agents.Wrappers.rllib_wrapper import RLlibWrapper
import warnings
import numpy as np
from ray import air, tune

from ray.rllib.algorithms.callbacks import DefaultCallbacks
from ray.rllib.policy.sample_batch import SampleBatch
from ray.rllib.env import BaseEnv
from ray.rllib.evaluation import Episode, RolloutWorker
from ray.rllib.policy import Policy
from typing import Dict

from ray.rllib.algorithms.ppo import PPOConfig
from ray.rllib.policy.policy import PolicySpec

warnings.filterwarnings('ignore')
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if (distutils.version.LooseVersion(tf.__version__) <

# %%
NUM_WORKER = 1
BATCH_SIZE = 4000
ITERS = 200
# RED_AGENT = "B_Line"
RED_AGENT = "Meander"
SCENARIO_PATH = '/Shared/Scenarios/Scenario2_No_Decoy.yaml'

DATA_PATH = f"logs/APPO/TrueStates_{ITERS}_{BATCH_SIZE}_{RED_AGENT}_badblue_nodecoys"

# %%
class CustomTrueStateCallbackSaver(DefaultCallbacks):
    def __init__(self, legacy_callbacks_dict: Dict[str, callable] = None):
        super().__init__(legacy_callbacks_dict=legacy_callbacks_dict)
        # self.id = next_id()
        # print(f"INIT A CALLBACKS {self.id}")
        self.worker_to_pres = {}
        self.worker_to_blues = {}
        self.worker_to_reds = {}
        self.worker_to_afterstates = {}

    def on_episode_end(
        self,
        *,
        worker: RolloutWorker,
        base_env: BaseEnv,
        policies: Dict[str, Policy],
        episode: Episode,
        env_index: int,
        **kwargs
    ):
        
        env = base_env.get_sub_environments()
        true_state_sequences = env[env_index].env.env.env.env.env.environment_controller.pop_additional_states_sequences()
        # print(f"worker = {worker}")
        # print(len(true_state_sequences),flush=True)
        # print(len(true_state_sequences[0]),flush=True)
        if len(true_state_sequences[0]) > 0:
            # print(true_state_sequences[0][30],flush=True)
            # print(true_state_sequences[1][30],flush=True)
            # print(true_state_sequences[2][30],flush=True)

            pres_np  = np.array(true_state_sequences[0])
            blues_np  = np.array(true_state_sequences[1])
            reds_np  = np.array(true_state_sequences[2])
            afterstates = np.array(true_state_sequences[3])

            if len(true_state_sequences[0]) > 1:
                red1_eq_pres0 = reds_np[:-1,:]==pres_np[1:,:]
                
                assert np.alltrue(red1_eq_pres0), "failed assumption that no true state change between post-red action and next pre-action states"
                
                # TODO: move these assers to end sample to test over the full batch
                # assert not np.all(pres_np==blues_np), "failed assumption that true state can change after blue and before red actions"
                assert not np.all(blues_np==reds_np), "failed assumption that true state can change after blue and red actions"

            if worker not in self.worker_to_pres:
                self.reset_worker_stores(worker)

            self.worker_to_pres[worker].append(pres_np) # np.concatenate(self.worker_to_pres[worker], pres_np)
            self.worker_to_blues[worker].append(blues_np) # = np.concatenate(self.worker_to_blues[worker], blues_np)
            self.worker_to_reds[worker].append(reds_np) # np.concatenate(self.worker_to_reds[worker], reds_np)
            self.worker_to_afterstates[worker].append(afterstates)

    def reset_worker_stores(self, worker):
        self.worker_to_pres[worker] = [] #np.array([[]],dtype=np.int64)
        self.worker_to_blues[worker] = [] # np.array([[]],dtype=np.int64)
        self.worker_to_reds[worker] = [] #np.array([[]],dtype=np.int64)
        self.worker_to_afterstates[worker] = []
    
    def on_sample_end(self, worker: RolloutWorker, samples: SampleBatch,
                      **kwargs):
        """Called at the end RolloutWorker.sample().

        Args:
            worker (RolloutWorker): Reference to the current rollout worker.
            samples (SampleBatch): Batch to be returned. You can mutate this
                object to modify the samples generated.
            kwargs: Forward compatibility placeholder.
        """

        # print(f"worker = {worker}")
        samples_len = len(samples['obs'])
        print(f"SAMPLES LEN = {samples_len}, is {len(samples['obs'])/100} sequences of 100, truncating true state arrays if they do not match")

        # Concat all runs into a single experience batch
        sample_pres = np.concatenate(self.worker_to_pres[worker])
        sample_blues = np.concatenate(self.worker_to_blues[worker])
        sample_reds = np.concatenate(self.worker_to_reds[worker])
        sample_afterstate = np.concatenate(self.worker_to_afterstates[worker])

        # Truncate and save to the SampleBatch dict
        samples["pre_action_true_states"] = sample_pres[:samples_len,:]
        samples["blue_action_true_states"] = sample_blues[:samples_len,:]
        samples["red_action_true_states"] = sample_reds[:samples_len,:]
        samples["afterstates"] = sample_afterstate[:samples_len,:]

        assert not np.all(sample_pres==sample_blues), "failed assumption that true state can change after blue and before red actions"
        assert not np.all(sample_blues==sample_reds), "failed assumption that true state can change after blue and red actions"

        self.reset_worker_stores(worker)
        # samples["yessss"]= np.array([len(samples['obs'])])

# %%
def env_creator(env_config: dict):
    # import pdb; pdb.set_trace()
    path = str(inspect.getfile(CybORG))
    path = path[:-10] + SCENARIO_PATH
    if RED_AGENT == "B_Line":
        agents = {"Red": B_lineAgent, "Green": GreenAgent}
    else:
        agents = {"Red": RedMeanderAgent, "Green": GreenAgent}

    cyborg = CybORG(scenario_file=path, environment='sim', agents=agents)
    env = RLlibWrapper(env=cyborg, agent_name="Blue", max_steps=100)
    return env

# %%
def print_results(results_dict):
    train_iter = results_dict["training_iteration"]
    r_mean = results_dict["episode_reward_mean"]
    r_max = results_dict["episode_reward_max"]
    r_min = results_dict["episode_reward_min"]
    print(f"{train_iter:4d} \tr_mean: {r_mean:.1f} \tr_max: {r_max:.1f} \tr_min: {r_min: .1f}")

# %%
register_env(name="CybORG", env_creator=env_creator)

# TODO: maybe add horizon to the callback initialiser
config = (
    PPOConfig()
    #Each rollout worker uses a single cpu
    .rollouts(num_rollout_workers=NUM_WORKER, num_envs_per_worker=1, horizon=100)\
    .training(train_batch_size=BATCH_SIZE, gamma=0.8, lr=0.00005, 
            # Swap the comments to get a bad agent or not (for true state capture/analysis purposes)
            #   model={"fcnet_hiddens": [512, 512], "fcnet_activation": "tanh",})\
                model={"fcnet_hiddens": [4, 4], "fcnet_activation": "tanh",})\
    .environment(disable_env_checking=True, env = 'CybORG')\
    # .resources(num_gpus=0)\
    .framework('tf')\
    # Swap the comments to get a bad agent or not (for true state capture/analysis purposes)
    # .exploration(explore=True, exploration_config={"type": "RE3", "embeds_dim": 128, "beta_schedule": "constant", "sub_exploration": {"type": "StochasticSampling",},})\
    .exploration(explore=True, exploration_config={"type": "RE3", "embeds_dim": 2, "beta_schedule": "constant", "sub_exploration": {"type": "StochasticSampling",},})\
    .offline_data(output=DATA_PATH, output_compress_columns=['prev_actions', 'prev_rewards', 'dones', 't', 'action_prob', 'action_logp', 'action_dist_inputs', 'advantages', 'value_targets'], #'eps_id', 'unroll_id', 'agent_index',
                 output_config={"format": "json"},)\
    .callbacks(CustomTrueStateCallbackSaver)
)
trainer = config.build() #use_copy=True
# Out:
# 2023-02-08 20:16:57,836	WARNING utils.py:636 -- Detecting docker specified CPUs. In previous versions of Ray, CPU detection in containers was incorrect. Please ensure that Ray has enough CPUs allocated. As a temporary workaround to revert to the prior behavior, set `RAY_USE_MULTIPROCESSING_CPU_COUNT=1` as an env var before starting Ray. Set the env var: `RAY_DISABLE_DOCKER_CPU_WARNING=1` to mute this warning.
# 2023-02-08 20:16:58,014	INFO worker.py:1529 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (pid=1915) /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# (pid=1915)   if (distutils.version.LooseVersion(tf.__version__) <
# 2023-02-08 20:17:10,751	INFO trainable.py:172 -- Trainable.setup took 15.519 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.

# %%
for i in range(ITERS):
    print_results(trainer.train())
# Out:
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#    1 	r_mean: -347.1 	r_max: -180.7 	r_min: -888.5
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#    2 	r_mean: -334.9 	r_max: -151.1 	r_min: -888.5
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#    3 	r_mean: -337.1 	r_max: -151.1 	r_min: -940.1
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#    4 	r_mean: -318.5 	r_max: -159.1 	r_min: -940.1
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#    5 	r_mean: -286.4 	r_max: -154.3 	r_min: -940.1
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#    6 	r_mean: -255.1 	r_max: -134.6 	r_min: -767.2
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#    7 	r_mean: -241.4 	r_max: -134.6 	r_min: -714.3
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#    8 	r_mean: -237.5 	r_max: -134.6 	r_min: -714.3
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#    9 	r_mean: -235.2 	r_max: -150.6 	r_min: -714.3
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   10 	r_mean: -221.6 	r_max: -158.7 	r_min: -379.4
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   11 	r_mean: -221.7 	r_max: -161.8 	r_min: -379.4
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   12 	r_mean: -216.7 	r_max: -161.8 	r_min: -287.6
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   13 	r_mean: -217.5 	r_max: -169.9 	r_min: -423.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   14 	r_mean: -214.2 	r_max: -143.5 	r_min: -423.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   15 	r_mean: -207.3 	r_max: -143.5 	r_min: -274.1
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   16 	r_mean: -208.5 	r_max: -150.1 	r_min: -276.6
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   17 	r_mean: -206.6 	r_max: -140.0 	r_min: -276.6
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   18 	r_mean: -203.5 	r_max: -140.0 	r_min: -276.6
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   19 	r_mean: -211.0 	r_max: -151.6 	r_min: -819.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   20 	r_mean: -213.7 	r_max: -134.9 	r_min: -819.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   21 	r_mean: -215.2 	r_max: -134.9 	r_min: -819.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   22 	r_mean: -205.9 	r_max: -144.1 	r_min: -487.6
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   23 	r_mean: -197.5 	r_max: -143.0 	r_min: -301.2
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   24 	r_mean: -199.0 	r_max: -143.0 	r_min: -440.2
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   25 	r_mean: -196.9 	r_max: -141.0 	r_min: -440.2
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   26 	r_mean: -193.6 	r_max: -141.0 	r_min: -348.4
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   27 	r_mean: -192.4 	r_max: -141.0 	r_min: -348.4
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   28 	r_mean: -192.7 	r_max: -144.2 	r_min: -281.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   29 	r_mean: -195.2 	r_max: -144.2 	r_min: -475.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   30 	r_mean: -199.0 	r_max: -123.7 	r_min: -481.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   31 	r_mean: -195.1 	r_max: -121.6 	r_min: -481.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   32 	r_mean: -190.3 	r_max: -121.6 	r_min: -481.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   33 	r_mean: -187.6 	r_max: -142.0 	r_min: -271.0
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   34 	r_mean: -193.3 	r_max: -148.9 	r_min: -299.3
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   35 	r_mean: -191.4 	r_max: -130.2 	r_min: -299.3
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   36 	r_mean: -189.4 	r_max: -124.4 	r_min: -299.3
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   37 	r_mean: -188.7 	r_max: -124.4 	r_min: -302.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   38 	r_mean: -189.9 	r_max: -141.3 	r_min: -344.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   39 	r_mean: -192.6 	r_max: -128.7 	r_min: -344.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   40 	r_mean: -190.2 	r_max: -128.7 	r_min: -344.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   41 	r_mean: -192.4 	r_max: -128.7 	r_min: -275.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   42 	r_mean: -196.4 	r_max: -152.2 	r_min: -291.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   43 	r_mean: -201.2 	r_max: -145.1 	r_min: -376.1
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   44 	r_mean: -198.9 	r_max: -136.9 	r_min: -376.1
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   45 	r_mean: -191.3 	r_max: -136.9 	r_min: -376.1
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   46 	r_mean: -196.1 	r_max: -142.3 	r_min: -595.1
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   47 	r_mean: -194.7 	r_max: -133.5 	r_min: -595.1
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   48 	r_mean: -192.1 	r_max: -133.5 	r_min: -541.7
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   49 	r_mean: -190.3 	r_max: -145.9 	r_min: -541.7
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   50 	r_mean: -192.1 	r_max: -147.1 	r_min: -541.7
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   51 	r_mean: -190.1 	r_max: -147.1 	r_min: -320.6
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   52 	r_mean: -188.8 	r_max: -151.6 	r_min: -320.6
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   53 	r_mean: -186.9 	r_max: -136.7 	r_min: -263.3
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   54 	r_mean: -188.9 	r_max: -136.7 	r_min: -296.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   55 	r_mean: -190.8 	r_max: -145.9 	r_min: -296.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   56 	r_mean: -191.4 	r_max: -149.3 	r_min: -494.3
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   57 	r_mean: -194.9 	r_max: -152.6 	r_min: -510.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   58 	r_mean: -193.0 	r_max: -147.8 	r_min: -510.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   59 	r_mean: -194.5 	r_max: -138.2 	r_min: -639.2
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   60 	r_mean: -191.4 	r_max: -138.2 	r_min: -639.2
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   61 	r_mean: -194.4 	r_max: -138.2 	r_min: -639.2
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   62 	r_mean: -190.8 	r_max: -142.6 	r_min: -485.2
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   63 	r_mean: -194.4 	r_max: -142.6 	r_min: -485.2
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   64 	r_mean: -190.8 	r_max: -149.0 	r_min: -373.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   65 	r_mean: -200.4 	r_max: -131.3 	r_min: -886.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   66 	r_mean: -198.1 	r_max: -131.3 	r_min: -886.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   67 	r_mean: -205.4 	r_max: -133.6 	r_min: -886.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   68 	r_mean: -195.9 	r_max: -133.6 	r_min: -563.0
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   69 	r_mean: -199.8 	r_max: -136.2 	r_min: -712.0
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   70 	r_mean: -198.9 	r_max: -145.6 	r_min: -712.0
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   71 	r_mean: -194.3 	r_max: -136.3 	r_min: -712.0
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   72 	r_mean: -192.2 	r_max: -136.3 	r_min: -837.7
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   73 	r_mean: -193.7 	r_max: -136.3 	r_min: -837.7
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   74 	r_mean: -191.3 	r_max: -136.4 	r_min: -837.7
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   75 	r_mean: -185.2 	r_max: -136.4 	r_min: -358.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   76 	r_mean: -187.2 	r_max: -145.0 	r_min: -358.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   77 	r_mean: -189.4 	r_max: -139.8 	r_min: -440.2
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   78 	r_mean: -184.8 	r_max: -136.3 	r_min: -440.2
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   79 	r_mean: -183.8 	r_max: -129.8 	r_min: -334.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   80 	r_mean: -189.2 	r_max: -129.8 	r_min: -380.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   81 	r_mean: -187.0 	r_max: -138.2 	r_min: -380.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   82 	r_mean: -183.9 	r_max: -126.8 	r_min: -380.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   83 	r_mean: -178.5 	r_max: -126.8 	r_min: -271.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   84 	r_mean: -188.9 	r_max: -128.7 	r_min: -708.1
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   85 	r_mean: -192.6 	r_max: -128.7 	r_min: -708.1
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   86 	r_mean: -188.9 	r_max: -128.7 	r_min: -708.1
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   87 	r_mean: -187.3 	r_max: -130.5 	r_min: -702.7
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   88 	r_mean: -197.0 	r_max: -130.5 	r_min: -702.7
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   89 	r_mean: -189.9 	r_max: -141.4 	r_min: -567.1
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   90 	r_mean: -185.4 	r_max: -118.8 	r_min: -567.1
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   91 	r_mean: -173.0 	r_max: -118.8 	r_min: -326.4
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   92 	r_mean: -172.4 	r_max: -131.5 	r_min: -326.4
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   93 	r_mean: -172.9 	r_max: -131.5 	r_min: -371.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   94 	r_mean: -175.3 	r_max: -132.7 	r_min: -371.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   95 	r_mean: -174.6 	r_max: -129.3 	r_min: -371.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   96 	r_mean: -171.9 	r_max: -129.3 	r_min: -444.7
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   97 	r_mean: -176.2 	r_max: -132.6 	r_min: -444.7
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   98 	r_mean: -182.8 	r_max: -123.0 	r_min: -679.3
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#   99 	r_mean: -177.0 	r_max: -123.0 	r_min: -679.3
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  100 	r_mean: -179.2 	r_max: -109.4 	r_min: -679.3
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  101 	r_mean: -180.3 	r_max: -109.4 	r_min: -799.7
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  102 	r_mean: -176.9 	r_max: -109.4 	r_min: -799.7
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  103 	r_mean: -175.2 	r_max: -115.0 	r_min: -540.7
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  104 	r_mean: -176.4 	r_max: -128.8 	r_min: -540.7
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  105 	r_mean: -176.9 	r_max: -126.4 	r_min: -540.7
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  106 	r_mean: -176.9 	r_max: -118.0 	r_min: -423.0
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  107 	r_mean: -174.4 	r_max: -118.0 	r_min: -423.0
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  108 	r_mean: -171.9 	r_max: -132.5 	r_min: -423.0
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  109 	r_mean: -165.8 	r_max: -132.5 	r_min: -296.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  110 	r_mean: -176.3 	r_max: -103.0 	r_min: -844.4
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  111 	r_mean: -177.5 	r_max: -103.0 	r_min: -844.4
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  112 	r_mean: -168.8 	r_max: -115.2 	r_min: -844.4
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  113 	r_mean: -165.2 	r_max: -114.7 	r_min: -366.6
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  114 	r_mean: -168.3 	r_max: -113.7 	r_min: -366.6
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  115 	r_mean: -177.9 	r_max: -113.7 	r_min: -563.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  116 	r_mean: -176.2 	r_max: -128.7 	r_min: -563.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  117 	r_mean: -174.0 	r_max: -128.7 	r_min: -563.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  118 	r_mean: -168.2 	r_max: -128.7 	r_min: -425.5
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  119 	r_mean: -164.2 	r_max: -116.9 	r_min: -305.3
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  120 	r_mean: -160.8 	r_max: -116.9 	r_min: -305.3
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  121 	r_mean: -163.1 	r_max: -119.2 	r_min: -260.1
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  122 	r_mean: -168.8 	r_max: -128.9 	r_min: -507.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  123 	r_mean: -166.4 	r_max: -128.9 	r_min: -507.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  124 	r_mean: -165.0 	r_max: -125.9 	r_min: -520.2
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  125 	r_mean: -163.9 	r_max: -120.5 	r_min: -520.2
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  126 	r_mean: -161.8 	r_max: -120.5 	r_min: -338.0
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  127 	r_mean: -164.7 	r_max: -120.7 	r_min: -425.1
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  128 	r_mean: -160.4 	r_max: -120.7 	r_min: -425.1
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  129 	r_mean: -165.3 	r_max: -121.0 	r_min: -425.1
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  130 	r_mean: -169.0 	r_max: -121.0 	r_min: -411.0
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  131 	r_mean: -165.7 	r_max: -117.9 	r_min: -411.0
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  132 	r_mean: -164.2 	r_max: -114.2 	r_min: -401.6
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  133 	r_mean: -164.5 	r_max: -114.2 	r_min: -401.6
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  134 	r_mean: -162.0 	r_max: -115.9 	r_min: -328.7
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  135 	r_mean: -168.3 	r_max: -115.9 	r_min: -698.6
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  136 	r_mean: -169.0 	r_max: -120.3 	r_min: -698.6
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  137 	r_mean: -170.8 	r_max: -118.0 	r_min: -698.6
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  138 	r_mean: -161.7 	r_max: -118.0 	r_min: -445.3
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  139 	r_mean: -161.8 	r_max: -110.3 	r_min: -465.2
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  140 	r_mean: -160.7 	r_max: -110.3 	r_min: -465.2
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  141 	r_mean: -159.4 	r_max: -110.3 	r_min: -465.2
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  142 	r_mean: -164.4 	r_max: -121.4 	r_min: -413.0
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  143 	r_mean: -165.5 	r_max: -126.2 	r_min: -413.0
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  144 	r_mean: -164.4 	r_max: -123.5 	r_min: -422.4
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  145 	r_mean: -161.3 	r_max: -109.3 	r_min: -422.4
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  146 	r_mean: -160.7 	r_max: -109.3 	r_min: -422.4
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  147 	r_mean: -163.9 	r_max: -124.1 	r_min: -441.4
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  148 	r_mean: -165.0 	r_max: -125.4 	r_min: -441.4
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  149 	r_mean: -163.7 	r_max: -122.1 	r_min: -492.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  150 	r_mean: -158.4 	r_max: -90.0 	r_min: -492.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  151 	r_mean: -156.7 	r_max: -90.0 	r_min: -379.6
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  152 	r_mean: -158.2 	r_max: -90.0 	r_min: -379.6
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  153 	r_mean: -157.6 	r_max: -114.8 	r_min: -264.3
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  154 	r_mean: -161.3 	r_max: -120.4 	r_min: -410.4
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  155 	r_mean: -163.9 	r_max: -123.2 	r_min: -450.3
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  156 	r_mean: -168.3 	r_max: -120.0 	r_min: -450.3
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  157 	r_mean: -162.7 	r_max: -120.0 	r_min: -310.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  158 	r_mean: -157.7 	r_max: -118.6 	r_min: -310.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  159 	r_mean: -154.3 	r_max: -116.1 	r_min: -304.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  160 	r_mean: -156.7 	r_max: -116.1 	r_min: -319.4
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  161 	r_mean: -155.8 	r_max: -116.4 	r_min: -319.4
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  162 	r_mean: -154.2 	r_max: -117.5 	r_min: -305.7
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  163 	r_mean: -159.1 	r_max: -119.1 	r_min: -332.4
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  164 	r_mean: -158.8 	r_max: -118.9 	r_min: -332.4
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  165 	r_mean: -157.0 	r_max: -118.9 	r_min: -332.4
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  166 	r_mean: -159.2 	r_max: -116.1 	r_min: -300.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  167 	r_mean: -157.3 	r_max: -114.8 	r_min: -262.5
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  168 	r_mean: -161.9 	r_max: -114.8 	r_min: -598.5
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  169 	r_mean: -165.0 	r_max: -114.8 	r_min: -598.5
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  170 	r_mean: -164.0 	r_max: -117.1 	r_min: -598.5
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  171 	r_mean: -155.3 	r_max: -117.1 	r_min: -328.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  172 	r_mean: -153.7 	r_max: -117.1 	r_min: -262.4
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  173 	r_mean: -152.4 	r_max: -106.4 	r_min: -276.7
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  174 	r_mean: -150.5 	r_max: -106.4 	r_min: -276.7
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  175 	r_mean: -149.5 	r_max: -106.4 	r_min: -332.4
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  176 	r_mean: -148.2 	r_max: -110.3 	r_min: -332.4
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  177 	r_mean: -152.8 	r_max: -110.3 	r_min: -354.7
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  178 	r_mean: -157.5 	r_max: -111.8 	r_min: -373.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  179 	r_mean: -157.2 	r_max: -114.4 	r_min: -373.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  180 	r_mean: -151.9 	r_max: -115.0 	r_min: -373.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  181 	r_mean: -148.0 	r_max: -114.5 	r_min: -274.5
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  182 	r_mean: -147.0 	r_max: -114.5 	r_min: -237.1
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  183 	r_mean: -143.4 	r_max: -97.4 	r_min: -237.1
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  184 	r_mean: -147.8 	r_max: -93.9 	r_min: -333.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  185 	r_mean: -145.8 	r_max: -93.9 	r_min: -333.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  186 	r_mean: -145.1 	r_max: -93.9 	r_min: -405.1
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  187 	r_mean: -146.4 	r_max: -100.5 	r_min: -405.1
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  188 	r_mean: -143.7 	r_max: -105.2 	r_min: -261.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  189 	r_mean: -145.7 	r_max: -104.3 	r_min: -364.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  190 	r_mean: -145.5 	r_max: -104.3 	r_min: -364.9
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  191 	r_mean: -140.6 	r_max: -104.3 	r_min: -272.6
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  192 	r_mean: -139.9 	r_max: -105.6 	r_min: -272.6
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  193 	r_mean: -140.8 	r_max: -93.0 	r_min: -272.6
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  194 	r_mean: -139.7 	r_max: -93.0 	r_min: -233.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  195 	r_mean: -142.8 	r_max: -98.7 	r_min: -332.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  196 	r_mean: -141.4 	r_max: -107.4 	r_min: -332.8
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  197 	r_mean: -137.8 	r_max: -105.3 	r_min: -250.2
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  198 	r_mean: -140.4 	r_max: -105.3 	r_min: -385.1
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  199 	r_mean: -148.8 	r_max: -102.5 	r_min: -507.0
# (RolloutWorker pid=1915) SAMPLES LEN = 4000, is 40.0 sequences of 100, truncating true state arrays if they do not match
#  200 	r_mean: -148.5 	r_max: -102.5 	r_min: -507.0
